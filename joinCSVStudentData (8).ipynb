# %%
import csv
import math
import time
import os.path
import datetime
import collections
import pandas as pd
import numpy as np
import scipy as sci
from sklearn import svm
from scipy import signal
import seaborn as sns
import matplotlib.pyplot as plt
import scipy.stats as stats
from collections import OrderedDict
from sklearn.preprocessing import StandardScaler
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import cross_val_score
from scipy.interpolate import UnivariateSpline
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import roc_curve
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier

# %% [markdown]
# # Data Wrangling - synchronization and concatenation of data

# %%
gravX = 0
gravY = 0
gravZ = 0

EDAHertz = 4
BVPHertz = 64
TEMPHertz = 4
ACCHertz = 32

# %%
def convertMilisToTime(milis):
    return time.strftime('%Y-%m-%d %H:%M:%S', time.gmtime(int(round(milis))))

def processAcceleration(x,y,z):
    #converting to G values:
    x = float(x) * 2/128
    y = float(y) * 2/128
    z = float(z) * 2/128
    #calculating effect of gravity
    alpha = 0.8
    global gravX
    global gravY
    global gravZ
    #Global variables for applying low pass filter on acceleration values
    gravX = alpha * gravX + (1 - alpha) * x;
    gravY = alpha * gravY + (1 - alpha) * y;
    gravZ = alpha * gravZ + (1 - alpha) * z;
    #removing gravity's effect
    x = x - gravX
    y = y - gravY
    z = z - gravZ
    #total acceleration from all 3 axes
    overall = math.sqrt(x*x+y*y+z*z)
    return {'x':x,'y':y,'z':z,'overall':overall}

# %%
def readFile(file):
    dict = OrderedDict()
    print("-->Reading file:" + file)
    with open(file, 'rt') as csvfile:
         reader = csv.reader(csvfile, delimiter='\n')
         i=0;
         for row in reader:
             if(i == 0):
                 timestamp=row[0]
                 timestamp = float(timestamp)+3600*2#converts from string to float rounds and then to int
             elif(i == 1):
                 hertz=float(row[0])
             elif(i == 2):
                 dict[timestamp]=row[0]
                 #print ', '.join(row)
             else:
                 timestamp = timestamp + 1.0/hertz
                 #print timestamp
                 #print convertMilisToTime(timestamp)
                 dict[timestamp]=row[0]
             #print "HR Timestamp:",timestamp," exact Time: ",convertMilisToTime(timestamp)
             i = i + 1.0
    return dict

# %%
def readAccFile(file):
    dict = OrderedDict()
    print("-->Reading file:" + file)
    with open(file, 'rt') as csvfile:
        reader = csv.reader(csvfile, delimiter=',')
        i=0;
        for row in reader:
            if(i == 0):
                timestamp = float(row[0])+3600*2#converts from string to float rounds and then to int
            elif(i == 1):
                hertz=float(row[0])
            elif(i == 2):
                dict[timestamp]= processAcceleration(row[0],row[1],row[2])
            else:
                timestamp = timestamp + 1.0/hertz
                dict[timestamp] = processAcceleration(row[0],row[1],row[2])
            i = i + 1

    return dict

# %%
#Reading IBI File
def readIBI_File(file):
    dict = OrderedDict()
    print("-->Reading file:" + file)
    with open(file, 'rt') as csvfile:
        reader = csv.reader(csvfile, delimiter = ',')
        initialTimestamp = 0.0
        i = 0;
        for row in reader:
            if(i == 0):
                initialTimestamp = float(row[0])+3600*2
                print("Initial Timestamp ",initialTimestamp," exact Time: ",convertMilisToTime(initialTimestamp))
            else:
                timestamp = initialTimestamp + round(float(row[0]),1)
                dict[timestamp] = float(row[1])
                #print "IBI timestamp",timestamp," exact Time: ",convertMilisToTime(timestamp)
            i = i + 1
    return dict

# %%
def process_data_vector(student_id, exam_id):
    __file__ = f"E:\Research\Capstone-smartwatch stress detector\Dataset\Data\{student_id}\{exam_id}"
    myDir = dir_path = os.path.dirname(os.path.realpath(__file__)) + f"\{exam_id}"
    participantID = os.path.split(os.path.abspath(myDir))[1] 

    outputFile = f"E:\Research\Capstone-smartwatch stress detector\processed_datatset\merged{student_id}{exam_id}.csv" #Setting name of output file
    print("Current Directory: ",myDir)
    print("Syncing data for Participant: ",participantID)
    print(myDir)

    ACC = {}
    ACC = readAccFile(myDir+'\ACC.csv')

    HR = {}
    HR = readFile(myDir+'\HR.csv')

    EDA = {}
    EDA = readFile(myDir+'\EDA.csv')

    BVP = {}
    BVP = readFile(myDir+'\BVP.csv')

    TEMP = {}
    TEMP = readFile(myDir+'\TEMP.csv')

    IBI = {}
    IBI = readIBI_File(myDir+'\IBI.csv')


    #merging all files at a sampling rate of 1 Hz
    count = 0 #count of how many timestamps are the same
    total = 0 #total of measurements with the same timestamp

    start_time = convertMilisToTime(time.time()+3600*2)

    with open(outputFile,'w') as f1:
        writer=csv.writer(f1, delimiter=',',lineterminator='\n',)
        row ="ID","Timestamp","Hour","HRV","EDA","BVP","TEMP","ACC_X","ACC_Y","ACC_Z","ACC_Overall","SumIBI","Beats"
        writer.writerow(row)
        for timestampHR, hr in HR.items():
            timestamp = convertMilisToTime(timestampHR)
            hour = timestamp.split(" ")#splitting timestamp and keeping hour for importing to SPSS
            #merging with EDA
            i = 0.0
            total = 0.0
            count = 0
            meanEDA = 0.0
            while i < 1.0:
                if (timestampHR + i in EDA):
                    total = total + float(EDA[timestampHR+i])
                    count = count+1
                i = i + 1.0/EDAHertz
            if(count > 0):
                meanEDA = total/count
            #print("Merging HRV and EDA at ", timestamp, " HRV: ",hr," EDA ",meanEDA, " count: ",count)
            #merging with BVP
            i = 0.0
            total = 0.0
            count = 0
            meanBVP = 0.0
            while i < 1.0:
                if (timestampHR + i in BVP):
                    total = total + float(BVP[timestampHR+i])
                    count = count+1
                i = i + 1.0/BVPHertz
            if(count > 0):
                meanBVP = total/count
            #print("Merging HRV and BVP at ", timestamp, " HRV: ",hr," BVP ",meanBVP, " count: ",count)
            #merging with TEMP
            i = 0.0
            total = 0.0
            count = 0
            meanTemp = 0.0
            while i < 1.0:
                if (timestampHR + i in TEMP):
                    total = total + float(TEMP[timestampHR+i])
                    count = count+1
                i = i + 1.0/TEMPHertz
            if(count > 0):
                meanTEMP = total/count
            #print("Merging HRV and TEM at ", timestamp, " HRV: ",hr," TEM ",meanTEMP, " count: ",count)
            #merging with ACC
            i = 0.0
            totalX = 0.0
            totalY = 0.0
            totalZ = 0.0
            totalOverall = 0.0
            count = 0
            meanX = 0.0
            meanY = 0.0
            meanZ = 0.0
            meanOverall = 0.0
            while i < 1.0:
                if (timestampHR + i in ACC):
                    totalX = totalX + float(ACC[timestampHR+i]['x'])
                    totalY = totalY + float(ACC[timestampHR+i]['y'])
                    totalZ = totalZ + float(ACC[timestampHR+i]['z'])
                    totalOverall = totalOverall + float(ACC[timestampHR+i]['overall'])
                    count = count+1
                i = i + 1.0/ACCHertz
            if(count > 0):
                meanX = totalX/count
                meanY = totalY/count
                meanZ = totalZ/count
                meanOverall = totalOverall/count
            #print("Merging HRV and ACC at ", timestamp, " HRV: ",hr," ACC ",meanOverall, " count: ",count)
            #merging with IBI in 1 second timeframes: Sums up all IBI occurring in 1 sec time frame.
            i = 0.0
            total = 0.0
            count = 0
            sumIBI = 0.0
            while i < 1.0:
                if(timestampHR + i in IBI):
                    #print "Timestamps matched-- HR:",timestampHR," IBI: ",timestampHR+i
                    total = total + float(IBI[timestampHR+i])
                    count = count + 1
                i = i + 0.1
            if(count > 0):
                sumIBI = total
            #print("Merging HRV and IBI at ", timestamp," milis: ",timestampHR," HRV: ",hr, " Sum IBI: ",sumIBI, " count: ",count)

            row = participantID,timestamp,hour[1],hr,meanEDA,meanBVP,meanTEMP,meanX,meanY,meanZ,meanOverall,sumIBI,count
            writer.writerow(row)
        
    print("--------------------------------------------------------------------------------")
    print("Synced data for Participant: ",participantID)
    print("Start time: ", start_time, " End time: ", convertMilisToTime(time.time()+3600*2))
    print("Results stored in ",outputFile)

# %% [markdown]
# # Reading and saving in specified folder

# %%
student_ids = [f"S{x}" for x in range(1, 11)]
exam_ids = ['Midterm 1', 'Midterm 2', 'Final']
for student_id in student_ids:
    for exam_id in exam_ids:
        print(f'Processing {student_id} for {exam_id}...')
        process_data_vector(student_id, exam_id)
        print(f'Processing {student_id} for {exam_id} done.')
# Out:
# Processing S1 for Midterm 1...
# Current Directory:  E:\Research\Capstone-smartwatch stress detector\Dataset\Data\S1\Midterm 1
# Syncing data for Participant:  Midterm 1
# E:\Research\Capstone-smartwatch stress detector\Dataset\Data\S1\Midterm 1
# -->Reading file:E:\Research\Capstone-smartwatch stress detector\Dataset\Data\S1\Midterm 1\ACC.csv
# -->Reading file:E:\Research\Capstone-smartwatch stress detector\Dataset\Data\S1\Midterm 1\HR.csv
# -->Reading file:E:\Research\Capstone-smartwatch stress detector\Dataset\Data\S1\Midterm 1\EDA.csv
# -->Reading file:E:\Research\Capstone-smartwatch stress detector\Dataset\Data\S1\Midterm 1\BVP.csv
# -->Reading file:E:\Research\Capstone-smartwatch stress detector\Dataset\Data\S1\Midterm 1\TEMP.csv
# -->Reading file:E:\Research\Capstone-smartwatch stress detector\Dataset\Data\S1\Midterm 1\IBI.csv
# Initial Timestamp  1539442566.0  exact Time:  2018-10-13 14:56:06
# --------------------------------------------------------------------------------
# Synced data for Participant:  Midterm 1
# Start time:  2023-03-19 18:51:35  End time:  2023-03-19 18:51:38
# Results stored in  E:\Research\Capstone-smartwatch stress detector\processed_datatset\mergedS1Midterm 1.csv
# Processing S1 for Midterm 1 done.
# Processing S1 for Midterm 2...
# Current Directory:  E:\Research\Capstone-smartwatch stress detector\Dataset\Data\S1\Midterm 2
# Syncing data for Participant:  Midterm 2
# E:\Research\Capstone-smartwatch stress detector\Dataset\Data\S1\Midterm 2
# -->Reading file:E:\Research\Capstone-smartwatch stress detector\Dataset\Data\S1\Midterm 2\ACC.csv
# -->Reading file:E:\Research\Capstone-smartwatch stress detector\Dataset\Data\S1\Midterm 2\HR.csv
# -->Reading file:E:\Research\Capstone-smartwatch stress detector\Dataset\Data\S1\Midterm 2\EDA.csv
# -->Reading file:E:\Research\Capstone-smartwatch stress detector\Dataset\Data\S1\Midterm 2\BVP.csv
# -->Reading file:E:\Research\Capstone-smartwatch stress detector\Dataset\Data\S1\Midterm 2\TEMP.csv
# -->Reading file:E:\Research\Capstone-smartwatch stress detector\Dataset\Data\S1\Midterm 2\IBI.csv
# Initial Timestamp  1541866755.0  exact Time:  2018-11-10 16:19:15
# --------------------------------------------------------------------------------
# Synced data for Participant:  Midterm 2
# Start time:  2023-03-19 18:51:43  End time:  2023-03-19 18:51:47
# Results stored in  E:\Research\Capstone-smartwatch stress detector\processed_datatset\mergedS1Midterm 2.csv
# Processing S1 for Midterm 2 done.
# Processing S1 for Final...
# Current Directory:  E:\Research\Capstone-smartwatch stress detector\Dataset\Data\S1\Final
# Syncing data for Participant:  Final
# E:\Research\Capstone-smartwatch stress detector\Dataset\Data\S1\Final
# -->Reading file:E:\Research\Capstone-smartwatch stress detector\Dataset\Data\S1\Final\ACC.csv
# -->Reading file:E:\Research\Capstone-smartwatch stress detector\Dataset\Data\S1\Final\HR.csv
# -->Reading file:E:\Research\Capstone-smartwatch stress detector\Dataset\Data\S1\Final\EDA.csv
# -->Reading file:E:\Research\Capstone-smartwatch stress detector\Dataset\Data\S1\Final\BVP.csv
# -->Reading file:E:\Research\Capstone-smartwatch stress detector\Dataset\Data\S1\Final\TEMP.csv
# -->Reading file:E:\Research\Capstone-smartwatch stress detector\Dataset\Data\S1\Final\IBI.csv
# Initial Timestamp  1544034537.0  exact Time:  2018-12-05 18:28:57
# --------------------------------------------------------------------------------
# Synced data for Participant:  Final
# Start time:  2023-03-19 18:52:00  End time:  2023-03-19 18:52:09
# Results stored in  E:\Research\Capstone-smartwatch stress detector\processed_datatset\mergedS1Final.csv
# Processing S1 for Final done.
# Processing S2 for Midterm 1...
# Current Directory:  E:\Research\Capstone-smartwatch stress detector\Dataset\Data\S2\Midterm 1
# Syncing data for Participant:  Midterm 1
# E:\Research\Capstone-smartwatch stress detector\Dataset\Data\S2\Midterm 1
# -->Reading file:E:\Research\Capstone-smartwatch stress detector\Dataset\Data\S2\Midterm 1\ACC.csv
# -->Reading file:E:\Research\Capstone-smartwatch stress detector\Dataset\Data\S2\Midterm 1\HR.csv
# -->Reading file:E:\Research\Capstone-smartwatch stress detector\Dataset\Data\S2\Midterm 1\EDA.csv
# -->Reading file:E:\Research\Capstone-smartwatch stress detector\Dataset\Data\S2\Midterm 1\BVP.csv
# -->Reading file:E:\Research\Capstone-smartwatch stress detector\Dataset\Data\S2\Midterm 1\TEMP.csv
# -->Reading file:E:\Research\Capstone-smartwatch stress detector\Dataset\Data\S2\Midterm 1\IBI.csv
# Initial Timestamp  1539442545.0  exact Time:  2018-10-13 14:55:45
# --------------------------------------------------------------------------------
# Synced data for Participant:  Midterm 1
# Start time:  2023-03-19 18:52:16  End time:  2023-03-19 18:52:20
# Results stored in  E:\Research\Capstone-smartwatch stress detector\processed_datatset\mergedS2Midterm 1.csv
# Processing S2 for Midterm 1 done.
# Processing S2 for Midterm 2...
# Current Directory:  E:\Research\Capstone-smartwatch stress detector\Dataset\Data\S2\Midterm 2
# Syncing data for Participant:  Midterm 2
# E:\Research\Capstone-smartwatch stress detector\Dataset\Data\S2\Midterm 2
# -->Reading file:E:\Research\Capstone-smartwatch stress detector\Dataset\Data\S2\Midterm 2\ACC.csv
# -->Reading file:E:\Research\Capstone-smartwatch stress detector\Dataset\Data\S2\Midterm 2\HR.csv
# -->Reading file:E:\Research\Capstone-smartwatch stress detector\Dataset\Data\S2\Midterm 2\EDA.csv
# -->Reading file:E:\Research\Capstone-smartwatch stress detector\Dataset\Data\S2\Midterm 2\BVP.csv
# -->Reading file:E:\Research\Capstone-smartwatch stress detector\Dataset\Data\S2\Midterm 2\TEMP.csv
# -->Reading file:E:\Research\Capstone-smartwatch stress detector\Dataset\Data\S2\Midterm 2\IBI.csv
# Initial Timestamp  1541866649.0  exact Time:  2018-11-10 16:17:29
# --------------------------------------------------------------------------------
# Synced data for Participant:  Midterm 2
# Start time:  2023-03-19 18:52:27  End time:  2023-03-19 18:52:32
# Results stored in  E:\Research\Capstone-smartwatch stress detector\processed_datatset\mergedS2Midterm 2.csv
# Processing S2 for Midterm 2 done.
# Processing S2 for Final...
# Current Directory:  E:\Research\Capstone-smartwatch stress detector\Dataset\Data\S2\Final
# Syncing data for Participant:  Final
# E:\Research\Capstone-smartwatch stress detector\Dataset\Data\S2\Final
# -->Reading file:E:\Research\Capstone-smartwatch stress detector\Dataset\Data\S2\Final\ACC.csv
# -->Reading file:E:\Research\Capstone-smartwatch stress detector\Dataset\Data\S2\Final\HR.csv
# -->Reading file:E:\Research\Capstone-smartwatch stress detector\Dataset\Data\S2\Final\EDA.csv
# -->Reading file:E:\Research\Capstone-smartwatch stress detector\Dataset\Data\S2\Final\BVP.csv
# -->Reading file:E:\Research\Capstone-smartwatch stress detector\Dataset\Data\S2\Final\TEMP.csv
# -->Reading file:E:\Research\Capstone-smartwatch stress detector\Dataset\Data\
# Results stored in  E:\Research\Capstone-smartwatch stress detector\processed_datatset\mergedS8Midterm 2.csv
# Processing S8 for Midterm 2 done.
# Processing S8 for Final...
# Current Directory:  E:\Research\Capstone-smartwatch stress detector\Dataset\Data\S8\Final
# Syncing data for Participant:  Final
# E:\Research\Capstone-smartwatch stress detector\Dataset\Data\S8\Final
# -->Reading file:E:\Research\Capstone-smartwatch stress detector\Dataset\Data\S8\Final\ACC.csv
# -->Reading file:E:\Research\Capstone-smartwatch stress detector\Dataset\Data\S8\Final\HR.csv
# -->Reading file:E:\Research\Capstone-smartwatch stress detector\Dataset\Data\S8\Final\EDA.csv
# -->Reading file:E:\Research\Capstone-smartwatch stress detector\Dataset\Data\S8\Final\BVP.csv
# -->Reading file:E:\Research\Capstone-smartwatch stress detector\Dataset\Data\S8\Final\TEMP.csv
# -->Reading file:E:\Research\Capstone-smartwatch stress detector\Dataset\Data\S8\Final\IBI.csv
# Initial Timestamp  1544034539.0  exact Time:  2018-12-05 18:28:59
# --------------------------------------------------------------------------------
# Synced data for Participant:  Final
# Start time:  2023-03-19 18:56:53  End time:  2023-03-19 18:57:00
# Results stored in  E:\Research\Capstone-smartwatch stress detector\processed_datatset\mergedS8Final.csv
# Processing S8 for Final done.
# Processing S9 for Midterm 1...
# Current Directory:  E:\Research\Capstone-smartwatch stress detector\Dataset\Data\S9\Midterm 1
# Syncing data for Participant:  Midterm 1
# E:\Research\Capstone-smartwatch stress detector\Dataset\Data\S9\Midterm 1
# -->Reading file:E:\Research\Capstone-smartwatch stress detector\Dataset\Data\S9\Midterm 1\ACC.csv
# -->Reading file:E:\Research\Capstone-smartwatch stress detector\Dataset\Data\S9\Midterm 1\HR.csv
# -->Reading file:E:\Research\Capstone-smartwatch stress detector\Dataset\Data\S9\Midterm 1\EDA.csv
# -->Reading file:E:\Research\Capstone-smartwatch stress detector\Dataset\Data\S9\Midterm 1\BVP.csv
# -->Reading file:E:\Research\Capstone-smartwatch stress detector\Dataset\Data\S9\Midterm 1\TEMP.csv
# -->Reading file:E:\Research\Capstone-smartwatch stress detector\Dataset\Data\S9\Midterm 1\IBI.csv
# Initial Timestamp  1539442565.0  exact Time:  2018-10-13 14:56:05
# --------------------------------------------------------------------------------
# Synced data for Participant:  Midterm 1
# Start time:  2023-03-19 18:57:06  End time:  2023-03-19 18:57:11
# Results stored in  E:\Research\Capstone-smartwatch stress detector\processed_datatset\mergedS9Midterm 1.csv
# Processing S9 for Midterm 1 done.
# Processing S9 for Midterm 2...
# Current Directory:  E:\Research\Capstone-smartwatch stress detector\Dataset\Data\S9\Midterm 2
# Syncing data for Participant:  Midterm 2
# E:\Research\Capstone-smartwatch stress detector\Dataset\Data\S9\Midterm 2
# -->Reading file:E:\Research\Capstone-smartwatch stress detector\Dataset\Data\S9\Midterm 2\ACC.csv
# -->Reading file:E:\Research\Capstone-smartwatch stress detector\Dataset\Data\S9\Midterm 2\HR.csv
# -->Reading file:E:\Research\Capstone-smartwatch stress detector\Dataset\Data\S9\Midterm 2\EDA.csv
# -->Reading file:E:\Research\Capstone-smartwatch stress detector\Dataset\Data\S9\Midterm 2\BVP.csv
# -->Reading file:E:\Research\Capstone-smartwatch stress detector\Dataset\Data\S9\Midterm 2\TEMP.csv
# -->Reading file:E:\Research\Capstone-smartwatch stress detector\Dataset\Data\S9\Midterm 2\IBI.csv
# Initial Timestamp  1541866655.0  exact Time:  2018-11-10 16:17:35
# --------------------------------------------------------------------------------
# Synced data for Participant:  Midterm 2
# Start time:  2023-03-19 18:57:18  End time:  2023-03-19 18:57:23
# Results stored in  E:\Research\Capstone-smartwatch stress detector\processed_datatset\mergedS9Midterm 2.csv
# Processing S9 for Midterm 2 done.
# Processing S9 for Final...
# Current Directory:  E:\Research\Capstone-smartwatch stress detector\Dataset\Data\S9\Final
# Syncing data for Participant:  Final
# E:\Research\Capstone-smartwatch stress detector\Dataset\Data\S9\Final
# -->Reading file:E:\Research\Capstone-smartwatch stress detector\Dataset\Data\S9\Final\ACC.csv
# -->Reading file:E:\Research\Capstone-smartwatch stress detector\Dataset\Data\S9\Final\HR.csv
# -->Reading file:E:\Research\Capstone-smartwatch stress detector\Dataset\Data\S9\Final\EDA.csv
# -->Reading file:E:\Research\Capstone-smartwatch stress detector\Dataset\Data\S9\Final\BVP.csv
# -->Reading file:E:\Research\Capstone-smartwatch stress detector\Dataset\Data\S9\Final\TEMP.csv
# -->Reading file:E:\Research\Capstone-smartwatch stress detector\Dataset\Data\S9\Final\IBI.csv
# Initial Timestamp  1544034547.0  exact Time:  2018-12-05 18:29:07
# --------------------------------------------------------------------------------
# Synced data for Participant:  Final
# Start time:  2023-03-19 18:57:31  End time:  2023-03-19 18:57:36
# Results stored in  E:\Research\Capstone-smartwatch stress detector\processed_datatset\mergedS9Final.csv
# Processing S9 for Final done.
# Processing S10 for Midterm 1...
# Current Directory:  E:\Research\Capstone-smartwatch stress detector\Dataset\Data\S10\Midterm 1
# Syncing data for Participant:  Midterm 1
# E:\Research\Capstone-smartwatch stress detector\Dataset\Data\S10\Midterm 1
# -->Reading file:E:\Research\Capstone-smartwatch stress detector\Dataset\Data\S10\Midterm 1\ACC.csv
# -->Reading file:E:\Research\Capstone-smartwatch stress detector\Dataset\Data\S10\Midterm 1\HR.csv
# -->Reading file:E:\Research\Capstone-smartwatch stress detector\Dataset\Data\S10\Midterm 1\EDA.csv
# -->Reading file:E:\Research\Capstone-smartwatch stress detector\Dataset\Data\S10\Midterm 1\BVP.csv
# -->Reading file:E:\Research\Capstone-smartwatch stress detector\Dataset\Data\S10\Midterm 1\TEMP.csv
# -->Reading file:E:\Research\Capstone-smartwatch stress detector\Dataset\Data\S10\Midterm 1\IBI.csv
# Initial Timestamp  1539442525.0  exact Time:  2018-10-13 14:55:25
# --------------------------------------------------------------------------------
# Synced data for Participant:  Midterm 1
# Start time:  2023-03-19 18:57:43  End time:  2023-03-19 18:57:48
# Results stored in  E:\Research\Capstone-smartwatch stress detector\processed_datatset\mergedS10Midterm 1.csv
# Processing S10 for Midterm 1 done.
# Processing S10 for Midterm 2...
# Current Directory:  E:\Research\Capstone-smartwatch stress detector\Dataset\Data\S10\Midterm 2
# Syncing data for Participant:  Midterm 2
# E:\Research\Capstone-smartwatch stress detector\Dataset\Data\S10\Midterm 2
# -->Reading file:E:\Research\Capstone-smartwatch stress detector\Dataset\Data\S10\Midterm 2\ACC.csv
# -->Reading file:E:\Research\Capstone-smartwatch stress detector\Dataset\Data\S10\Midterm 2\HR.csv
# -->Reading file:E:\Research\Capstone-smartwatch stress detector\Dataset\Data\S10\Midterm 2\EDA.csv
# -->Reading file:E:\Research\Capstone-smartwatch stress detector\Dataset\Data\S10\Midterm 2\BVP.csv
# -->Reading file:E:\Research\Capstone-smartwatch stress detector\Dataset\Data\S10\Midterm 2\TEMP.csv
# -->Reading file:E:\Research\Capstone-smartwatch stress detector\Dataset\Data\S10\Midterm 2\IBI.csv
# Initial Timestamp  1541866725.0  exact Time:  2018-11-10 16:18:45
# --------------------------------------------------------------------------------
# Synced data for Participant:  Midterm 2
# Start time:  2023-03-19 18:57:55  End time:  2023-03-19 18:58:00
# Results stored in  E:\Research\Capstone-smartwatch stress detector\processed_datatset\mergedS10Midterm 2.csv
# Processing S10 for Midterm 2 done.
# Processing S10 for Final...
# Current Directory:  E:\Research\Capstone-smartwatch stress detector\Dataset\Data\S10\Final
# Syncing data for Participant:  Final
# E:\Research\Capstone-smartwatch stress detector\Dataset\Data\S10\Final
# -->Reading file:E:\Research\Capstone-smartwatch stress detector\Dataset\Data\S10\Final\ACC.csv
# -->Reading file:E:\Research\Capstone-smartwatch stress detector\Dataset\Data\S10\Final\HR.csv
# -->Reading file:E:\Research\Capstone-smartwatch stress detector\Dataset\Data\S10\Final\EDA.csv
# -->Reading file:E:\Research\Capstone-smartwatch stress detector\Dataset\Data\S10\Final\BVP.csv
# -->Reading file:E:\Research\Capstone-smartwatch stress detector\Dataset\Data\S10\Final\TEMP.csv
# -->Reading file:E:\Research\Capstone-smartwatch stress detector\Dataset\Data\S10\Final\IBI.csv
# Initial Timestamp  1544034534.0  exact Time:  2018-12-05 18:28:54
# --------------------------------------------------------------------------------
# Synced data for Participant:  Final
# Start time:  2023-03-19 18:58:13  End time:  2023-03-19 18:58:22
# Results stored in  E:\Research\Capstone-smartwatch stress detector\processed_datatset\mergedS10Final.csv
# Processing S10 for Final done.

# %%
#yhat = sci.signal.savgol_filter(df["EDA"], 21, 3) #EDA filtered with Savitzky-Golay window size 21, polynomial order 3
#df["FilterEDA"]= yhat
#yhat = sci.signal.savgol_filter(df["FilterEDA"], 501, 3) # window size 51, polynomial order 3
#df["NEDA"]= yhat
#df['EDA'] = df['NEDA'].values
